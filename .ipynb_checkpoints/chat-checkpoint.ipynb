# %%
import random
import json

import torch

from model import NeuralNet
from nltk_utils import bag_of_words, tokenize

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

with open('intents.json', 'r') as json_data:
    intents = json.load(json_data)

FILE = "data.pth"
data = torch.load(FILE)

input_size = data["input_size"]
hidden_size = data["hidden_size"]
output_size = data["output_size"]
all_words = data['all_words']
tags = data['tags']
model_state = data["model_state"]

model = NeuralNet(input_size, hidden_size, output_size).to(device)
model.load_state_dict(model_state)
model.eval()

bot_name = "Sam"
print("Let's chat! (type 'quit' to exit)")
while True:
    # sentence = "do you use credit cards?"
    sentence = input("You: ")
    if sentence == "quit":
        break

    sentence = tokenize(sentence)
    X = bag_of_words(sentence, all_words)
    X = X.reshape(1, X.shape[0])
    X = torch.from_numpy(X).to(device)

    output = model(X)
    _, predicted = torch.max(output, dim=1)

    tag = tags[predicted.item()]

    probs = torch.softmax(output, dim=1)
    prob = probs[0][predicted.item()]
    if prob.item() > 0.75:
        for intent in intents['intents']:
            if tag == intent["tag"]:
                print(f"{bot_name}: {random.choice(intent['responses'])}")
    else:
        print(f"{bot_name}: I do not understand...")
# Out:
# Let's chat! (type 'quit' to exit)
# You: where is ngit located?
# Sam: NGIT is located in Parvathapur, Kachawanisingaram Village, Hyderabad, Telangana, India.
# You: what courses does ngit offer?
# Sam: The institute offers undergraduate courses in Computer Science Engineering and Artificial Intelligence & Machine learning.
# You: who is the chairman?
# Sam: I do not understand...
# You: who is neil gogte?
# Sam: It enhances the educational experience through theoretical sessions, programming tasks, and real-time feedback.
# You: what is project school?
# Sam: Project School at NGIT provides students with a well-rounded skill set through hands-on experience with end-to-end projects.
# You: when do students have finsihing school?
# Sam: Get ready to showcase your skills and compete in exciting contests organized by NGIT throughout the academic year.
# You: when did ngit start?
# Sam: I do not understand...
# You: tell me about your college?
# Sam: NGIT organizes various events throughout the year, including technical fests, cultural events, and workshops.
# You: Placement statistics at NGIT
# Sam: At present, more than 100 companies have been flooding NGIT to recruit students.
# You: what is fees?
# Sam: Tuition Fees per year are Rs. 90,000 and Special fees per year are Rs. 5,500.
# You: tell me about transport?
# Sam: Neil Gogte Institute of Technology (NGIT) is the first engineering college to have started after the formation of Telangana state.
# You: Tell me about NGIT Finishing School?
# Sam: NGIT's Finishing School program is designed to prepare engineering students for the industry by providing hands-on training and practical skills.
# You: ngit affiliation?
# Sam: I do not understand...
# You: accredition?
# Sam: Yes, NGIT is approved by the All India Council for Technical Education (AICTE), New Delhi.
# You: does ngit have hostel?
# Sam: Hey :-)
# You: does college provide hostel
# Sam: Explore the technology initiatives and projects that showcase NGIT's commitment to staying ahead in the field of engineering.
# You: is there a hostel at ngit
# Sam: For details on hostel accommodation, including fees and amenities, contact the hostel administration.
# You: what is student code of conduct
# Sam: NGIT encourages research activities, providing students with opportunities to engage in innovative projects.
